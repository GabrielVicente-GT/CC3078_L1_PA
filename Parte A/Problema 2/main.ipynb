# %%
from unidecode import unidecode

def analizar_frecuencia_letras(ruta_archivo):

    frecuencia_letras = {}

    total_letras = 0

    with open(ruta_archivo, 'r', encoding='utf-8') as archivo:

        contenido = archivo.read()

        for caracter in contenido:

            if caracter.isalpha():
                letra = unidecode(caracter).lower()

                frecuencia_letras[letra] = frecuencia_letras.get(letra, 0) + 1
                total_letras += 1

    return frecuencia_letras, total_letras

def mostrar_porcentajes(frecuencia_letras, total_letras):

    for letra in sorted(frecuencia_letras.keys()):
        frecuencia = frecuencia_letras[letra]
        porcentaje = (frecuencia / total_letras) * 100
        print(f'Letra: {letra}, Porcentaje: {porcentaje:.2f}%')

ruta_archivo = "../Problema 1/Cifrado Cesar/encriptado.txt"
print(f"\n{ruta_archivo}\n")
frecuencia_letras, total_letras = analizar_frecuencia_letras(ruta_archivo)
mostrar_porcentajes(frecuencia_letras, total_letras)
ruta_archivo = "../Problema 1/Cifrado afín/encriptado.txt"
print(f"\n{ruta_archivo}\n")
frecuencia_letras, total_letras = analizar_frecuencia_letras(ruta_archivo)
mostrar_porcentajes(frecuencia_letras, total_letras)
ruta_archivo = "../Problema 1/Cifrado Vigenére/encriptado.txt"
print(f"\n{ruta_archivo}\n")
frecuencia_letras, total_letras = analizar_frecuencia_letras(ruta_archivo)
mostrar_porcentajes(frecuencia_letras, total_letras)
# Out:
# ../Problema 1/Cifrado Cesar/encriptado.txt
#
# Letra: a, Porcentaje: 0.29%
# Letra: b, Porcentaje: 0.78%
# Letra: c, Porcentaje: 0.93%
# Letra: d, Porcentaje: 12.11%
# Letra: e, Porcentaje: 1.23%
# Letra: f, Porcentaje: 4.51%
# Letra: g, Porcentaje: 3.97%
# Letra: h, Porcentaje: 14.51%
# Letra: i, Porcentaje: 1.47%
# Letra: j, Porcentaje: 0.39%
# Letra: k, Porcentaje: 0.29%
# Letra: l, Porcentaje: 4.51%
# Letra: m, Porcentaje: 0.44%
# Letra: n, Porcentaje: 6.81%
# Letra: o, Porcentaje: 3.19%
# Letra: p, Porcentaje: 8.53%
# Letra: q, Porcentaje: 0.05%
# Letra: r, Porcentaje: 8.63%
# Letra: s, Porcentaje: 1.91%
# Letra: t, Porcentaje: 0.69%
# Letra: u, Porcentaje: 5.98%
# Letra: v, Porcentaje: 9.41%
# Letra: w, Porcentaje: 4.17%
# Letra: x, Porcentaje: 4.02%
# Letra: y, Porcentaje: 1.18%
#
# ../Problema 1/Cifrado afín/encriptado.txt
#
# Letra: a, Porcentaje: 4.31%
# Letra: b, Porcentaje: 14.51%
# Letra: c, Porcentaje: 8.63%
# Letra: d, Porcentaje: 0.93%
# Letra: e, Porcentaje: 0.15%
# ...
